# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# Unzip the dataset
# !unzip "/content/gdrive/MyDrive/CNN_assignment.zip" > /dev/null

# %%
# Defining the path for train and test images
data_dir_train = pathlib.Path("/content/CNN_assignment/Train")
data_dir_test = pathlib.Path("/content/CNN_assignment/Test")

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Training dataset
## Using seed=123 while creating dataset using tf.keras.preprocessing.image_dataset_from_directory
## Resizing images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(data_dir_train,
                                                               seed=123,
                                                               validation_split=0.2,
                                                               image_size=(img_height,img_width),
                                                               batch_size=batch_size,
                                                               color_mode='rgb',
                                                               subset='training')
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Validation dataset
## Using seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Resizing images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(data_dir_train,
                                                             seed=123,
                                                             validation_split=0.2,
                                                             image_size=(img_height,img_width),
                                                             batch_size=batch_size,
                                                             color_mode='rgb',
                                                             subset='validation')
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
## Testing dataset
## Using seed=123 while creating dataset using tf.keras.preprocessing.image_dataset_from_directory
## Resizing images to the size img_height*img_width, while writting the dataset
test_ds = tf.keras.preprocessing.image_dataset_from_directory(data_dir_test,
                                                             seed=123,
                                                             image_size=(img_height,img_width),
                                                             batch_size=batch_size,
                                                             color_mode='rgb')
# Out:
# Found 118 files belonging to 9 classes.

# %%
# List out all the classes of skin cancer and store them in a list. 
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### Create a code to visualize one instance of all the nine classes present in the dataset

# %%
image = plt.imread((list(data_dir_train.glob(class_names[0]+'/*.jpg'))[0]))
plt.imshow(image)

# %%
plt.figure(figsize=(25,8))
for i in range(len(class_names)):
  plt.subplot(2,5,i+1)
  image= plt.imread(str(list(data_dir_train.glob(class_names[i]+'/*.jpg'))[1]))
  plt.title(class_names[i])
  plt.imshow(image)

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
# Configure the dataset for performance

AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
# Method to create plots of the loss and accuracy on the training and validation sets:
def plot_cnn_metrics(history,epochs):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(epochs)

    plt.figure(figsize=(8, 8))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()

# %% [markdown]
# ### Create the model
# #### Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
model= Sequential()
# scaling the pixel values from 0-255 to 0-1
model.add(layers.Rescaling(scale=1./255,input_shape=(180,180,3)))

# Convolution layer with 64 features, 3x3 filter and relu activation with 2x2 pooling
model.add(layers.Conv2D(64,(3,3),padding = 'same',activation='relu'))
model.add(layers.MaxPooling2D())

# Convolution layer with 128 features, 3x3 filter and relu activation with 2x2 pooling
model.add(layers.Conv2D(128,(3,3),padding = 'same',activation='relu'))
model.add(layers.MaxPooling2D())

model.add(layers.Flatten())
model.add(layers.Dense(256,activation='relu'))
model.add(layers.Dense(9,activation='softmax'))

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 64)      1792
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 128)       73856
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 259200)            0
#
#  dense (Dense)               (None, 256)               66355456
#
#  dense_1 (Dense)             (None, 9)                 2313
#
# =================================================================
# Total params: 66,433,417
# Trainable params: 66,433,417
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 30s 147ms/step - loss: 2.7706 - accuracy: 0.2930 - val_loss: 1.6110 - val_accuracy: 0.5078
# Epoch 2/20
# 56/56 [==============================] - 4s 68ms/step - loss: 1.5440 - accuracy: 0.4676 - val_loss: 1.4370 - val_accuracy: 0.5213
# Epoch 3/20
# 56/56 [==============================] - 4s 68ms/step - loss: 1.3191 - accuracy: 0.5346 - val_loss: 1.4029 - val_accuracy: 0.5391
# Epoch 4/20
# 56/56 [==============================] - 4s 75ms/step - loss: 1.2244 - accuracy: 0.5731 - val_loss: 1.3922 - val_accuracy: 0.5213
# Epoch 5/20
# 56/56 [==============================] - 4s 69ms/step - loss: 1.1228 - accuracy: 0.6110 - val_loss: 1.5934 - val_accuracy: 0.4430
# Epoch 6/20
# 56/56 [==============================] - 4s 68ms/step - loss: 0.9897 - accuracy: 0.6529 - val_loss: 1.5444 - val_accuracy: 0.5034
# Epoch 7/20
# 56/56 [==============================] - 4s 70ms/step - loss: 0.8560 - accuracy: 0.6936 - val_loss: 1.7230 - val_accuracy: 0.4609
# Epoch 8/20
# 56/56 [==============================] - 4s 69ms/step - loss: 0.8126 - accuracy: 0.7254 - val_loss: 1.8263 - val_accuracy: 0.5593
# Epoch 9/20
# 56/56 [==============================] - 4s 68ms/step - loss: 0.6606 - accuracy: 0.7612 - val_loss: 1.8153 - val_accuracy: 0.5257
# Epoch 10/20
# 56/56 [==============================] - 4s 68ms/step - loss: 0.5808 - accuracy: 0.7891 - val_loss: 1.7467 - val_accuracy: 0.5168
# Epoch 11/20
# 56/56 [==============================] - 4s 71ms/step - loss: 0.4744 - accuracy: 0.8331 - val_loss: 1.9762 - val_accuracy: 0.5235
# Epoch 12/20
# 56/56 [==============================] - 4s 68ms/step - loss: 0.4726 - accuracy: 0.8426 - val_loss: 2.1976 - val_accuracy: 0.5190
# Epoch 13/20
# 56/56 [==============================] - 4s 68ms/step - loss: 0.4235 - accuracy: 0.8493 - val_loss: 2.0837 - val_accuracy: 0.5213
# Epoch 14/20
# 56/56 [==============================] - 4s 71ms/step - loss: 0.3500 - accuracy: 0.8761 - val_loss: 2.3885 - val_accuracy: 0.5101
# Epoch 15/20
# 56/56 [==============================] - 4s 68ms/step - loss: 0.3650 - accuracy: 0.8828 - val_loss: 2.3035 - val_accuracy: 0.5548
# Epoch 16/20
# 56/56 [==============================] - 4s 68ms/step - loss: 0.3079 - accuracy: 0.8856 - val_loss: 2.3566 - val_accuracy: 0.5257
# Epoch 17/20
# 56/56 [==============================] - 4s 70ms/step - loss: 0.2647 - accuracy: 0.8973 - val_loss: 2.3754 - val_accuracy: 0.4966
# Epoch 18/20
# 56/56 [==============================] - 4s 69ms/step - loss: 0.2562 - accuracy: 0.9018 - val_loss: 2.2530 - val_accuracy: 0.5056
# Epoch 19/20
# 56/56 [==============================] - 4s 68ms/step - loss: 0.3019 - accuracy: 0.8878 - val_loss: 2.7441 - val_accuracy: 0.4653
# Epoch 20/20
# 56/56 [==============================] - 4s 69ms/step - loss: 0.2881 - accuracy: 0.8884 - val_loss: 2.3995 - val_accuracy: 0.5011

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Findings:
#
# 1. Training accuracy increases linearly to 88%, where as the validation accuracy is at 50% accuracy in training process, this shows overfitting
#
# 2. Training loss decreases and validation loss increases with increase in epochs

# %% [markdown]
# ### Choosing an appropriate data augmentation strategy to resolve underfitting/overfitting

# %%
# After analysing the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",input_shape=(img_height,img_width,3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)

# %%
# Visualize how your augmentation strategy works for one instance of training image.
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# ### Model Building & training on the augmented data

# %%
model = Sequential()
# scaling the pixel values from 0-255 to 0-1
model.add(layers.Rescaling(scale=1./255,input_shape=(180,180,3)))

# adding the augmentation layer before the convolution layer
model.add(data_augmentation)

# Convolution layer with 64 features, 3x3 filter and relu activation with 2x2 pooling
model.add(layers.Conv2D(64,(3,3),padding = 'same',activation='relu'))
model.add(layers.MaxPooling2D())

# Convolution layer with 128 features, 3x3 filter and relu activation with 2x2 pooling
model.add(layers.Conv2D(128,(3,3),padding = 'same',activation='relu'))
model.add(layers.MaxPooling2D())

model.add(layers.Flatten())
model.add(layers.Dense(256,activation='relu'))
model.add(layers.Dense(9,activation='softmax'))

# %% [markdown]
# ### Compiling the model

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  sequential_1 (Sequential)   (None, 180, 180, 3)       0
#
#  conv2d_2 (Conv2D)           (None, 180, 180, 64)      1792
#
#  max_pooling2d_2 (MaxPooling  (None, 90, 90, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 90, 90, 128)       73856
#
#  max_pooling2d_3 (MaxPooling  (None, 45, 45, 128)      0
#  2D)
#
#  flatten_1 (Flatten)         (None, 259200)            0
#
#  dense_2 (Dense)             (None, 256)               66355456
#
#  dense_3 (Dense)             (None, 9)                 2313
#
# =================================================================
# Total params: 66,433,417
# Trainable params: 66,433,417
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 6s 72ms/step - loss: 2.7553 - accuracy: 0.2494 - val_loss: 1.8479 - val_accuracy: 0.3177
# Epoch 2/20
# 56/56 [==============================] - 4s 70ms/step - loss: 1.7116 - accuracy: 0.3817 - val_loss: 1.5585 - val_accuracy: 0.4631
# Epoch 3/20
# 56/56 [==============================] - 4s 70ms/step - loss: 1.5987 - accuracy: 0.4336 - val_loss: 1.5521 - val_accuracy: 0.4877
# Epoch 4/20
# 56/56 [==============================] - 4s 69ms/step - loss: 1.4668 - accuracy: 0.4816 - val_loss: 1.4993 - val_accuracy: 0.5011
# Epoch 5/20
# 56/56 [==============================] - 4s 70ms/step - loss: 1.4452 - accuracy: 0.4967 - val_loss: 1.5894 - val_accuracy: 0.4609
# Epoch 6/20
# 56/56 [==============================] - 4s 69ms/step - loss: 1.4256 - accuracy: 0.4905 - val_loss: 1.4610 - val_accuracy: 0.5324
# Epoch 7/20
# 56/56 [==============================] - 4s 69ms/step - loss: 1.3816 - accuracy: 0.5156 - val_loss: 1.5093 - val_accuracy: 0.5235
# Epoch 8/20
# 56/56 [==============================] - 4s 71ms/step - loss: 1.3407 - accuracy: 0.5312 - val_loss: 1.4309 - val_accuracy: 0.5168
# Epoch 9/20
# 56/56 [==============================] - 4s 71ms/step - loss: 1.2937 - accuracy: 0.5285 - val_loss: 1.3977 - val_accuracy: 0.5302
# Epoch 10/20
# 56/56 [==============================] - 4s 69ms/step - loss: 1.2502 - accuracy: 0.5508 - val_loss: 1.3724 - val_accuracy: 0.5190
# Epoch 11/20
# 56/56 [==============================] - 4s 69ms/step - loss: 1.2431 - accuracy: 0.5681 - val_loss: 1.4539 - val_accuracy: 0.5302
# Epoch 12/20
# 56/56 [==============================] - 4s 69ms/step - loss: 1.2512 - accuracy: 0.5625 - val_loss: 1.8264 - val_accuracy: 0.4385
# Epoch 13/20
# 56/56 [==============================] - 4s 68ms/step - loss: 1.2941 - accuracy: 0.5424 - val_loss: 1.4699 - val_accuracy: 0.5280
# Epoch 14/20
# 56/56 [==============================] - 4s 71ms/step - loss: 1.2052 - accuracy: 0.5709 - val_loss: 1.4155 - val_accuracy: 0.5481
# Epoch 15/20
# 56/56 [==============================] - 4s 70ms/step - loss: 1.1328 - accuracy: 0.5831 - val_loss: 1.4235 - val_accuracy: 0.5548
# Epoch 16/20
# 56/56 [==============================] - 4s 69ms/step - loss: 1.1846 - accuracy: 0.5603 - val_loss: 1.4136 - val_accuracy: 0.5347
# Epoch 17/20
# 56/56 [==============================] - 4s 69ms/step - loss: 1.1207 - accuracy: 0.6021 - val_loss: 1.5469 - val_accuracy: 0.5257
# Epoch 18/20
# 56/56 [==============================] - 4s 70ms/step - loss: 1.1249 - accuracy: 0.5826 - val_loss: 1.3623 - val_accuracy: 0.5324
# Epoch 19/20
# 56/56 [==============================] - 4s 68ms/step - loss: 1.0743 - accuracy: 0.6099 - val_loss: 1.3572 - val_accuracy: 0.5302
# Epoch 20/20
# 56/56 [==============================] - 4s 69ms/step - loss: 1.0636 - accuracy: 0.6211 - val_loss: 1.4723 - val_accuracy: 0.5168

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# Findings:
#
# 1. Training accuracy increases linearly to 62%, where as the validation accuracy is at 51% accuracy in training process, the model is not training well
#
# 2. The plots show that gap between training accuracy and validation accuracy have decreased from previous model, and it has achieved around 51% accuracy on the validation set

# %% [markdown]
# ### Model Building & training on the augmented data with dropout

# %%
model = Sequential()
# scaling the pixel values from 0-255 to 0-1
model.add(layers.Rescaling(scale=1./255,input_shape=(180,180,3)))
model.add(data_augmentation)

# Convolution layer with 64 features, 3x3 filter and relu activation with 2x2 pooling
model.add(layers.Conv2D(64,(3,3),padding = 'same',activation='relu'))
model.add(layers.MaxPooling2D())

# Convolution layer with 128 features, 3x3 filter and relu activation with 2x2 pooling
model.add(layers.Conv2D(128,(3,3),padding = 'same',activation='relu'))
model.add(layers.MaxPooling2D())
#adding a 20% dropout after the convolution layers
model.add(layers.Dropout(0.2))

model.add(layers.Flatten())
model.add(layers.Dense(256,activation='relu'))
model.add(layers.Dense(9,activation='softmax'))

# %% [markdown]
# ### Compiling the model

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_2 (Rescaling)     (None, 180, 180, 3)       0
#
#  sequential_1 (Sequential)   (None, 180, 180, 3)       0
#
#  conv2d_4 (Conv2D)           (None, 180, 180, 64)      1792
#
#  max_pooling2d_4 (MaxPooling  (None, 90, 90, 64)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 90, 90, 128)       73856
#
#  max_pooling2d_5 (MaxPooling  (None, 45, 45, 128)      0
#  2D)
#
#  dropout (Dropout)           (None, 45, 45, 128)       0
#
#  flatten_2 (Flatten)         (None, 259200)            0
#
#  dense_4 (Dense)             (None, 256)               66355456
#
#  dense_5 (Dense)             (None, 9)                 2313
#
# =================================================================
# Total params: 66,433,417
# Trainable params: 66,433,417
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 8s 114ms/step - loss: 3.5957 - accuracy: 0.1864 - val_loss: 2.0813 - val_accuracy: 0.2013
# Epoch 2/20
# 56/56 [==============================] - 6s 113ms/step - loss: 1.9520 - accuracy: 0.2489 - val_loss: 1.8767 - val_accuracy: 0.3378
# Epoch 3/20
# 56/56 [==============================] - 6s 112ms/step - loss: 1.8048 - accuracy: 0.3398 - val_loss: 1.8091 - val_accuracy: 0.4228
# Epoch 4/20
# 56/56 [==============================] - 6s 114ms/step - loss: 1.6599 - accuracy: 0.3945 - val_loss: 1.5418 - val_accuracy: 0.4474
# Epoch 5/20
# 56/56 [==============================] - 6s 114ms/step - loss: 1.6437 - accuracy: 0.4012 - val_loss: 1.5878 - val_accuracy: 0.4653
# Epoch 6/20
# 56/56 [==============================] - 6s 115ms/step - loss: 1.5852 - accuracy: 0.4275 - val_loss: 1.5617 - val_accuracy: 0.4631
# Epoch 7/20
# 56/56 [==============================] - 6s 114ms/step - loss: 1.5085 - accuracy: 0.4520 - val_loss: 1.5644 - val_accuracy: 0.4787
# Epoch 8/20
# 56/56 [==============================] - 6s 115ms/step - loss: 1.4555 - accuracy: 0.4799 - val_loss: 1.4925 - val_accuracy: 0.4810
# Epoch 9/20
# 56/56 [==============================] - 6s 113ms/step - loss: 1.4311 - accuracy: 0.4805 - val_loss: 1.6492 - val_accuracy: 0.4519
# Epoch 10/20
# 56/56 [==============================] - 6s 115ms/step - loss: 1.4007 - accuracy: 0.4933 - val_loss: 1.4390 - val_accuracy: 0.5123
# Epoch 11/20
# 56/56 [==============================] - 6s 112ms/step - loss: 1.3461 - accuracy: 0.5201 - val_loss: 1.4590 - val_accuracy: 0.5347
# Epoch 12/20
# 56/56 [==============================] - 6s 114ms/step - loss: 1.3280 - accuracy: 0.5229 - val_loss: 1.4744 - val_accuracy: 0.4877
# Epoch 13/20
# 56/56 [==============================] - 6s 112ms/step - loss: 1.2719 - accuracy: 0.5435 - val_loss: 1.4284 - val_accuracy: 0.5123
# Epoch 14/20
# 56/56 [==============================] - 6s 112ms/step - loss: 1.2849 - accuracy: 0.5385 - val_loss: 1.4150 - val_accuracy: 0.5123
# Epoch 15/20
# 56/56 [==============================] - 6s 113ms/step - loss: 1.3016 - accuracy: 0.5346 - val_loss: 1.4635 - val_accuracy: 0.5123
# Epoch 16/20
# 56/56 [==============================] - 6s 112ms/step - loss: 1.2339 - accuracy: 0.5603 - val_loss: 1.3834 - val_accuracy: 0.5034
# Epoch 17/20
# 56/56 [==============================] - 6s 113ms/step - loss: 1.2603 - accuracy: 0.5508 - val_loss: 1.4559 - val_accuracy: 0.5145
# Epoch 18/20
# 56/56 [==============================] - 6s 110ms/step - loss: 1.1961 - accuracy: 0.5681 - val_loss: 1.4575 - val_accuracy: 0.5056
# Epoch 19/20
# 56/56 [==============================] - 6s 109ms/step - loss: 1.2882 - accuracy: 0.5312 - val_loss: 1.4325 - val_accuracy: 0.5145
# Epoch 20/20
# 56/56 [==============================] - 6s 111ms/step - loss: 1.1901 - accuracy: 0.5698 - val_loss: 1.3700 - val_accuracy: 0.5213

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ### Findings:
#
# 1. Training accuracy and validation accuracy increases linearly at 57% and 52% accuracy respectively in training process
#
# 2. Training loss and validation loss decreases with increase in epochs
#
# 3. The plots show that gap between training accuracy and validation accuracy have decreased from previous model
#
# 3. The accuracy of training and validation is very low

# %% [markdown]
# #### We can clearly see that the overfitting of the model has redused significantly when compared the earlier models

# %% [markdown]
# #### Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
for i in range(len(class_names)):
  print(class_names[i],' - ',len(list(data_dir_train.glob(class_names[i]+'/*.jpg'))))
# Out:
# actinic keratosis  -  114
# basal cell carcinoma  -  376
# dermatofibroma  -  95
# melanoma  -  438
# nevus  -  357
# pigmented benign keratosis  -  462
# seborrheic keratosis  -  77
# squamous cell carcinoma  -  181
# vascular lesion  -  139

# %% [markdown]
# ### Which class has the least number of samples?
# ### **seborrheic keratosis with 77 samples**
# ### Which classes dominate the data in terms proportionate number of samples?
# ### **pigmented benign keratosis with 462 samples**

# %% [markdown]
# #### Handling class imbalances

# %%
# !pip install Augmentor
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Augmentor
#   Downloading Augmentor-0.2.12-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.9/dist-packages (from Augmentor) (1.22.4)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.9/dist-packages (from Augmentor) (8.4.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.9/dist-packages (from Augmentor) (4.65.0)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.12

# %%
path_to_training_dataset="/content/CNN_assignment/Train/"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/CNN_assignment/Train/actinic keratosis/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7F14602B7BE0>: 100%|██████████| 500/500 [00:23<00:00, 21.02 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/CNN_assignment/Train/basal cell carcinoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7F1460273340>: 100%|██████████| 500/500 [00:22<00:00, 21.85 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/CNN_assignment/Train/dermatofibroma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7F146026F3D0>: 100%|██████████| 500/500 [00:18<00:00, 26.42 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/CNN_assignment/Train/melanoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1936x1296 at 0x7F14602EDBB0>: 100%|██████████| 500/500 [01:31<00:00,  5.45 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/CNN_assignment/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=1504x1129 at 0x7F14604A7F40>: 100%|██████████| 500/500 [01:38<00:00,  5.10 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/CNN_assignment/Train/pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F146022FAF0>: 100%|██████████| 500/500 [00:19<00:00, 25.07 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/CNN_assignment/Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F14604A7F70>: 100%|██████████| 500/500 [00:46<00:00, 10.86 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /content/CNN_assignment/Train/squamous cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F147869F610>: 100%|██████████| 500/500 [00:18<00:00, 27.23 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to /content/CNN_assignment/Train/vascular lesion/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7F14602D4190>: 100%|██████████| 500/500 [00:20<00:00, 24.51 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
from glob import glob
path_list_new = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]

# %%
dataframe_dict_new = dict(zip(path_list_new, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
df2['Label'].value_counts()
# Out:
# dermatofibroma                500
# vascular lesion               500
# actinic keratosis             500
# squamous cell carcinoma       500
# pigmented benign keratosis    500
# nevus                         500
# basal cell carcinoma          500
# seborrheic keratosis          500
# melanoma                      500
# Name: Label, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### Create a training dataset

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = "training",
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# #### Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = "validation",
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %% [markdown]
# #### Create your model

# %%
model = Sequential()
# scaling the pixel values from 0-255 to 0-1
model.add(layers.Rescaling(scale=1./255,input_shape=(180,180,3)))
model.add(data_augmentation)

# Convolution layer with 64 features, 3x3 filter and relu activation with 2x2 pooling
model.add(layers.Conv2D(64,(3,3),padding = 'same',activation='relu'))
model.add(layers.MaxPooling2D())

# Convolution layer with 128 features, 3x3 filter and relu activation with 2x2 pooling
model.add(layers.Conv2D(128,(3,3),padding = 'same',activation='relu'))
model.add(layers.MaxPooling2D())
#adding a 20% dropout after the convolution layers
model.add(layers.Dropout(0.2))

model.add(layers.Flatten())
model.add(layers.Dense(256,activation='relu'))
model.add(layers.Dense(9,activation='softmax'))

# %% [markdown]
# #### Compile your model

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_3 (Rescaling)     (None, 180, 180, 3)       0
#
#  sequential_1 (Sequential)   (None, 180, 180, 3)       0
#
#  conv2d_6 (Conv2D)           (None, 180, 180, 64)      1792
#
#  max_pooling2d_6 (MaxPooling  (None, 90, 90, 64)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 90, 90, 128)       73856
#
#  max_pooling2d_7 (MaxPooling  (None, 45, 45, 128)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 45, 45, 128)       0
#
#  flatten_3 (Flatten)         (None, 259200)            0
#
#  dense_6 (Dense)             (None, 256)               66355456
#
#  dense_7 (Dense)             (None, 9)                 2313
#
# =================================================================
# Total params: 66,433,417
# Trainable params: 66,433,417
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Train your model

# %%
epochs = 30
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 169/169 [==============================] - 34s 182ms/step - loss: 2.0254 - accuracy: 0.3236 - val_loss: 1.5248 - val_accuracy: 0.3957
# Epoch 2/30
# 169/169 [==============================] - 31s 178ms/step - loss: 1.4923 - accuracy: 0.4306 - val_loss: 1.4242 - val_accuracy: 0.4625
# Epoch 3/30
# 169/169 [==============================] - 31s 178ms/step - loss: 1.3936 - accuracy: 0.4681 - val_loss: 1.4870 - val_accuracy: 0.4395
# Epoch 4/30
# 169/169 [==============================] - 31s 179ms/step - loss: 1.3321 - accuracy: 0.4948 - val_loss: 1.2545 - val_accuracy: 0.5419
# Epoch 5/30
# 169/169 [==============================] - 37s 213ms/step - loss: 1.2580 - accuracy: 0.5215 - val_loss: 1.2870 - val_accuracy: 0.4915
# Epoch 6/30
# 169/169 [==============================] - 32s 185ms/step - loss: 1.1962 - accuracy: 0.5473 - val_loss: 1.1477 - val_accuracy: 0.5531
# Epoch 7/30
# 169/169 [==============================] - 32s 185ms/step - loss: 1.1488 - accuracy: 0.5614 - val_loss: 1.0632 - val_accuracy: 0.6043
# Epoch 8/30
# 169/169 [==============================] - 31s 178ms/step - loss: 1.0968 - accuracy: 0.5812 - val_loss: 0.9988 - val_accuracy: 0.6251
# Epoch 9/30
# 169/169 [==============================] - 33s 185ms/step - loss: 1.0569 - accuracy: 0.6031 - val_loss: 1.0214 - val_accuracy: 0.6206
# Epoch 10/30
# 169/169 [==============================] - 31s 178ms/step - loss: 0.9920 - accuracy: 0.6246 - val_loss: 0.9933 - val_accuracy: 0.6451
# Epoch 11/30
# 169/169 [==============================] - 31s 181ms/step - loss: 0.9277 - accuracy: 0.6563 - val_loss: 0.9758 - val_accuracy: 0.6481
# Epoch 12/30
# 169/169 [==============================] - 31s 179ms/step - loss: 0.9408 - accuracy: 0.6474 - val_loss: 0.9619 - val_accuracy: 0.6459
# Epoch 13/30
# 169/169 [==============================] - 33s 188ms/step - loss: 0.8820 - accuracy: 0.6677 - val_loss: 0.9069 - val_accuracy: 0.6733
# Epoch 14/30
# 169/169 [==============================] - 31s 179ms/step - loss: 0.8214 - accuracy: 0.6827 - val_loss: 0.9194 - val_accuracy: 0.6949
# Epoch 15/30
# 169/169 [==============================] - 31s 180ms/step - loss: 0.8445 - accuracy: 0.6866 - val_loss: 0.8897 - val_accuracy: 0.6674
# Epoch 16/30
# 169/169 [==============================] - 31s 180ms/step - loss: 0.7985 - accuracy: 0.7022 - val_loss: 0.9545 - val_accuracy: 0.6912
# Epoch 17/30
# 169/169 [==============================] - 33s 188ms/step - loss: 0.7544 - accuracy: 0.7177 - val_loss: 0.8667 - val_accuracy: 0.6860
# Epoch 18/30
# 169/169 [==============================] - 35s 203ms/step - loss: 0.7500 - accuracy: 0.7183 - val_loss: 0.8260 - val_accuracy: 0.7201
# Epoch 19/30
# 169/169 [==============================] - 31s 177ms/step - loss: 0.6876 - accuracy: 0.7435 - val_loss: 0.8574 - val_accuracy: 0.7060
# Epoch 20/30
# 169/169 [==============================] - 33s 187ms/step - loss: 0.6871 - accuracy: 0.7404 - val_loss: 0.8691 - val_accuracy: 0.7097
# Epoch 21/30
# 169/169 [==============================] - 31s 177ms/step - loss: 0.6633 - accuracy: 0.7539 - val_loss: 0.8258 - val_accuracy: 0.7268
# Epoch 22/30
# 169/169 [==============================] - 31s 179ms/step - loss: 0.5956 - accuracy: 0.7771 - val_loss: 0.7598 - val_accuracy: 0.7528
# Epoch 23/30
# 169/169 [==============================] - 31s 178ms/step - loss: 0.5960 - accuracy: 0.7778 - val_loss: 0.8087 - val_accuracy: 0.7565
# Epoch 24/30
# 169/169 [==============================] - 31s 178ms/step - loss: 0.5927 - accuracy: 0.7778 - val_loss: 0.7350 - val_accuracy: 0.7654
# Epoch 25/30
# 169/169 [==============================] - 31s 178ms/step - loss: 0.5766 - accuracy: 0.7917 - val_loss: 0.8071 - val_accuracy: 0.7513
# Epoch 26/30
# 169/169 [==============================] - 32s 183ms/step - loss: 0.5372 - accuracy: 0.7982 - val_loss: 0.7073 - val_accuracy: 0.7936
# Epoch 27/30
# 169/169 [==============================] - 32s 182ms/step - loss: 0.5083 - accuracy: 0.8127 - val_loss: 0.8576 - val_accuracy: 0.7387
# Epoch 28/30
# 169/169 [==============================] - 32s 183ms/step - loss: 0.4702 - accuracy: 0.8309 - val_loss: 0.7209 - val_accuracy: 0.7728
# Epoch 29/30
# 169/169 [==============================] - 32s 179ms/step - loss: 0.5217 - accuracy: 0.8047 - val_loss: 0.7669 - val_accuracy: 0.7758
# Epoch 30/30
# 169/169 [==============================] - 31s 177ms/step - loss: 0.4757 - accuracy: 0.8242 - val_loss: 0.7425 - val_accuracy: 0.7921

# %% [markdown]
# #### Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## Findings:
#
# ## 1. Class rebalancing removed the overfitting as well as improved the accuracy from 57% to 82%
# ## 2. Training loss decreased with increase in epochs
# ## 3. The difference between training accuracy and validation accuracy has reduced in the latest model showing good model convergence
